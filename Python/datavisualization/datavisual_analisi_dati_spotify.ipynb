# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Andrea C\Desktop\its\Py\datascience\data_visual\spotify_songs.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
df[df.track_name.isna()]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# ...

# %%
print('Righe :',df.shape[0])
print('Track :',df.track_id.nunique())
print('Track album id : ',df.track_album_id.nunique())
print('Playlist ID :', df.playlist_id.nunique())
# Out:
# Righe : 32833
# Track : 28356
# Track album id :  22545
# Playlist ID : 471

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_artist, track_popularity, track_album_id, track_album_name, track_album_release_date, playlist_name, playlist_id, playlist_genre, playlist_subgenre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.track_id
# Out:
# 0        6f807x0ima9a1j3VPbc7VN
# 1        0r7CVbZTWZgbTCYdfa2P31
# 2        1z1Hg7Vb0AhHDiEmnDE79l
# 3        75FpbthrwQmzHlBJLuGdC7
# 4        1e8PAfcKUYoKkxPhrHqw4x
#                   ...
# 32828    7bxnKAamR3snQ1VGLuVfC1
# 32829    5Aevni09Em4575077nkWHz
# 32830    7ImMqPP3Q1yfUHvsdn7wEo
# 32831    2m69mhnfQ1Oq6lGtXuYhgX
# 32832    29zWqhca3zt5NsckZqDf6c
# Name: track_id, Length: 32833, dtype: object

# %%
df.isna().sum()

df = df.dropna(subset=['track_name','track_artist','track_album_name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32828 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32828 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32828 non-null  int64
#  4   track_album_id            32828 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32828 non-null  object
#  7   playlist_name             32828 non-null  object
#  8   playlist_id               32828 non-null  object
#  9   playlist_genre            32828 non-null  object
#  10  playlist_subgenre         32828 non-null  object
#  11  danceability              32828 non-null  float64
#  12  energy                    32828 non-null  float64
# ...

# %%
df.reset_index(drop=True)

df.index = range(1,32829)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32828 entries, 1 to 32828
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32828 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32828 non-null  int64
#  4   track_album_id            32828 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32828 non-null  object
#  7   playlist_name             32828 non-null  object
#  8   playlist_id               32828 non-null  object
#  9   playlist_genre            32828 non-null  object
#  10  playlist_subgenre         32828 non-null  object
#  11  danceability              32828 non-null  float64
#  12  energy                    32828 non-null  float64
# ...

# %%
df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df['track_album_release_date'] = pd.to_datetime(df['track_album_release_date'])
#
# File c:\Users\Andrea C\Desktop\its\Py\datascience\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File c:\Users\Andrea C\Desktop\its\Py\datascience\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# ...

# %%
#risoluzione

df[(df.track_album_release_date == '2012')]
# Out:
#                      track_id  \
# 152    2QtJA4gbwe1AcanB2p21aP
# 1257   3cHyrEgdyYRjgJKSOiOtcS
# 1444   6FE2iI43OZnszFLuLtvvmg
# 1598   3cHyrEgdyYRjgJKSOiOtcS
# 2907   3cHyrEgdyYRjgJKSOiOtcS
# 4106   6yOIdK2nKErlhyo5u7y81B
# 5140   5JFkuKQsPps2ZaZzaLx63d
# 5141   5Q5sQ1AgLQ1wKKXIYt6FGC
# 6193   2P3SLxeQHPqh8qKB6gtJY2
# 6923   2cDCojn6uIBM6A5xTAbl3H
# 6943   3aGibUHhQyBsyumYHylw0K
# 6979   1eRBW1HcyM1zPlxO26cScZ
# 9773   1nSPlJY53DG3avK6UfpDpZ
# 11366  4Z4zFrdGLhkXXJj6nOcpoQ
# 13631  31Tp5iKrVUayn65qhg06nE
# 17506  0CjaLvAqN97KPVWgOJ1vbD
# 17532  7vd2YXwqxAG2BGuEUoMzGl
# 17970  5DzPwr4r52gVeODKCjONWK
# 18034  6J0b8ypSQ2qEGQlC84ENGt
# 18035  0KBMx9uErneRij9qMvIplC
# 18036  69CoL4qoSXH3bApbvFKJf8
# 18038  2X7MSx6evV1iu9joWm33dt
# 18039  0GELYeRttonISErFwFf5QJ
# 18050  0aO50JeAEI5ArPOPsD5lwi
# 18051  2W5prz0WS9yWOEq3w0ZzSB
# 18097  6i9ipwB7w8dFwHYz3Mge0C
# 19140  3fNnPoIaVT16aLZnswQdCV
# 21171  0x8UEAzjwj3Cs9v9lQjUQm
# 21180  3NXrGwbbnIDrd955fReQQq
# 21300  3fNnPoIaVT16aLZnswQdCV
# ...

# %%
df_test_lambda = df.copy(deep=True)

df_test_npwhere = df.copy(deep=True)

# %%
df_test_npwhere['track_album_release_date'] = np.where(df_test_npwhere['track_album_release_date'] == '2012',np.nan,df_test_npwhere['track_album_release_date'])

# %%
df_test_lambda['track_album_release_date'] = df_test_lambda['track_album_release_date'].apply(lambda row: np.nan if row == '2012' else row )

# %%
df_test_lambda[df_test_lambda.track_album_release_date.isna()]
# Out:
#                      track_id  \
# 152    2QtJA4gbwe1AcanB2p21aP
# 1257   3cHyrEgdyYRjgJKSOiOtcS
# 1444   6FE2iI43OZnszFLuLtvvmg
# 1598   3cHyrEgdyYRjgJKSOiOtcS
# 2907   3cHyrEgdyYRjgJKSOiOtcS
# 4106   6yOIdK2nKErlhyo5u7y81B
# 5140   5JFkuKQsPps2ZaZzaLx63d
# 5141   5Q5sQ1AgLQ1wKKXIYt6FGC
# 6193   2P3SLxeQHPqh8qKB6gtJY2
# 6923   2cDCojn6uIBM6A5xTAbl3H
# 6943   3aGibUHhQyBsyumYHylw0K
# 6979   1eRBW1HcyM1zPlxO26cScZ
# 9773   1nSPlJY53DG3avK6UfpDpZ
# 11366  4Z4zFrdGLhkXXJj6nOcpoQ
# 13631  31Tp5iKrVUayn65qhg06nE
# 17506  0CjaLvAqN97KPVWgOJ1vbD
# 17532  7vd2YXwqxAG2BGuEUoMzGl
# 17970  5DzPwr4r52gVeODKCjONWK
# 18034  6J0b8ypSQ2qEGQlC84ENGt
# 18035  0KBMx9uErneRij9qMvIplC
# 18036  69CoL4qoSXH3bApbvFKJf8
# 18038  2X7MSx6evV1iu9joWm33dt
# 18039  0GELYeRttonISErFwFf5QJ
# 18050  0aO50JeAEI5ArPOPsD5lwi
# 18051  2W5prz0WS9yWOEq3w0ZzSB
# 18097  6i9ipwB7w8dFwHYz3Mge0C
# 19140  3fNnPoIaVT16aLZnswQdCV
# 21171  0x8UEAzjwj3Cs9v9lQjUQm
# 21180  3NXrGwbbnIDrd955fReQQq
# 21300  3fNnPoIaVT16aLZnswQdCV
# ...

# %%
df = df_test_lambda.copy(deep=True)

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 1  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 2  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 3  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 4  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 5  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 1        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 2          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 3      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 4  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 5     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
df.fillna('2012')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32828 entries, 1 to 32828
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32828 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32828 non-null  int64
#  4   track_album_id            32828 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32779 non-null  object
#  7   playlist_name             32828 non-null  object
#  8   playlist_id               32828 non-null  object
#  9   playlist_genre            32828 non-null  object
#  10  playlist_subgenre         32828 non-null  object
#  11  danceability              32828 non-null  float64
#  12  energy                    32828 non-null  float64
# ...

# %%
df_test_apply = df.copy(deep=True)
# Out:
#                      track_id  \
# 1      6f807x0ima9a1j3VPbc7VN
# 2      0r7CVbZTWZgbTCYdfa2P31
# 3      1z1Hg7Vb0AhHDiEmnDE79l
# 4      75FpbthrwQmzHlBJLuGdC7
# 5      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32824  7bxnKAamR3snQ1VGLuVfC1
# 32825  5Aevni09Em4575077nkWHz
# 32826  7ImMqPP3Q1yfUHvsdn7wEo
# 32827  2m69mhnfQ1Oq6lGtXuYhgX
# 32828  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 1      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 2                        Memories - Dillon Francis Remix          Maroon 5
# 3                        All the Time - Don Diablo Remix      Zara Larsson
# 4                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 5                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df_test_npwhere['track_album_release_date_TEST'] = np.where(df_test_npwhere['track_album_release_date1'])
