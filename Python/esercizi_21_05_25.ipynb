# %%
#1
import random
emptylist = []

for n in range(10):
    randomsnumer = random.randint(1,100)
    emptylist.append(randomsnumer)


print(emptylist)

#1.1

print(emptylist[:3])

print(emptylist[:-3:-1])

print(emptylist[1::2])


b = len(emptylist)
# Out:
# [82, 17, 49, 69, 28, 63, 93, 81, 26, 51]
# [82, 17, 49]
# [51, 26]
# [17, 69, 63, 81, 51]

# %%
#2

set(emptylist)
tuple(emptylist)

dizio = {}

for n,e in enumerate(emptylist):
    dizio.update({n:e})
    


print(dizio)
    
#3

sorted(emptylist)
sorted(emptylist, reverse=True)

print(max(emptylist))
print(min(emptylist))

a = max(emptylist)
b = min(emptylist)
print(a-b)

lista_pari = []

for x in emptylist:
    if x % 2 == 0:
        lista_pari.append(x)
        
print(lista_pari)
########################

product = 1

for e in lista_pari:
    product = e*product


print(product)
# Out:
# {0: 82, 1: 17, 2: 49, 3: 69, 4: 28, 5: 63, 6: 93, 7: 81, 8: 26, 9: 51}
# 93
# 17
# 76
# [82, 28, 26]
# 59696

# %%
#es 2
#parte 1

strin = "Python è un linguaggio versatile molto usato in Data Science"
vocount = 0
conscount = 0

for e in strin:
    if e in 'aeiou' or e in 'AEIOU':
        vocount +=1
    else :
        conscount+=1



print (vocount,conscount)

#2.2

splitted = strin.split()
i = 0

for e in splitted:
    splitted[i] = e.capitalize()
    i+=1    

print(splitted)

#2.3

for e in splitted:
    if len(e) > 4:
        print(e)

#2.4
alist = []

for e in splitted:
    length = len(e)
    alist.append(length)


print(alist)

#2.5

blist = []

for e in splitted:
    blist.append(e[::-1])


print(blist)

#2.6

adict = {}

for e in splitted:
    adict[e] = len(e) 

print(adict)

#2.7
i = 0
clist = []

for e in strin:
   if e in strin:
       clist.append(e)
    

print(clist)
# Out:
# 22 38
# ['Python', 'È', 'Un', 'Linguaggio', 'Versatile', 'Molto', 'Usato', 'In', 'Data', 'Science']
# Python
# Linguaggio
# Versatile
# Molto
# Usato
# Science
# [6, 1, 2, 10, 9, 5, 5, 2, 4, 7]
# ['nohtyP', 'È', 'nU', 'oiggaugniL', 'elitasreV', 'otloM', 'otasU', 'nI', 'ataD', 'ecneicS']
# {'Python': 6, 'È': 1, 'Un': 2, 'Linguaggio': 10, 'Versatile': 9, 'Molto': 5, 'Usato': 5, 'In': 2, 'Data': 4, 'Science': 7}
# []
